# %%
import pandas as pd
import pickle as p

# %%
coordinates=pd.read_csv("../DATA/FirstSample.csv",encoding="utf-8")
colleges=pd.read_csv("../DATA/Colleges.csv",encoding="utf-8")

# %%
with open("../DATA/CollegeObjects.dat","rb") as f:
    collegeOP=p.load(f)
with open("../DATA/Locations.dat","rb") as f:
    locationsOP=p.load(f)

# %%
coordinates.head(3)
# Out:
#                              Name                                DMS  \
# 0  Hospital Providence of El Paso   ((31, 46, 14.0), (106, 30, 1.6))
# 1           Palmas Medical Center  ((31, 46, 12.3), (106, 29, 56.6))
# 2        Kindred Hospital El Paso  ((31, 46, 43.4), (106, 28, 38.1))
#
#                                           DD     LatitudeDMS     LongitudeDMS  \
# 0  (31.770555555555553, -106.50044444444444)  (31, 46, 14.0)   (106, 30, 1.6)
# 1  (31.770083333333332, -106.49905555555556)  (31, 46, 12.3)  (106, 29, 56.6)
# 2            (31.77872222222222, -106.47725)  (31, 46, 43.4)  (106, 28, 38.1)
#
#    LatitudeDD  LongitudeDD                                               UUID
# 0   31.770556  -106.500444  35e4669582787d810f35a1ec46d821755a7a1152bf82b9...
# 1   31.770083  -106.499056  b0183dbf6ed43aa75e1e27368240da6b7f98e913a2a63d...
# 2   31.778722  -106.477250  371675f5d9f01d9fa841d5f4cf13db37e358d424e253e3...

# %%
locationsOP
# Out:
# OrderedDict([('Name',
#               ['Hospital Providence of El Paso',
#                'Palmas Medical Center',
#                'Kindred Hospital El Paso',
#                'El Paso Speciality Hospital',
#                'El Paso LTAC Hospital',
#                'Las Palmas Rehabilitation Center',
#                'Complete Care Community Hospital',
#                'William Beaumont Army Medical Center',
#                'University Medical Center Foundation',
#                'Hospital of Providence East Campus',
#                'Del Sol Medical Center']),
#              ('DMS',
#               [((31, 46, 14.0), (106, 30, 1.6)),
#                ((31, 46, 12.3), (106, 29, 56.6)),
#                ((31, 46, 43.4), (106, 28, 38.1)),
#                ((31, 46, 43.4), (106, 28, 39.0)),
#                ((31, 47, 1.6), (106, 28, 27.3)),
#                ((31, 47, 20.5), (106, 30, 31.9)),
#                ((31, 48, 3.6), (106, 30, 36.1)),
# ...

# %%
colleges.head(3)
# Out:
#    Unnamed: 0                                Name             Address  \
# 0           0  Community College of the Air Force  130 W Maxwell Blvd
# 1           1  Community College of the Air Force  130 W Maxwell Blvd
# 2           2            Alabama A & M University    4900 Meridian St
#
#          City         Zip                          Web  \
# 0  Montgomery  36112-6613  www.maxwell.af.mil/au/ccaf/
# 1  Montgomery  36112-6613  www.maxwell.af.mil/au/ccaf/
# 2      Normal       35762                www.aamu.edu/
#
#                                         Program Name
# 0                                                NaN
# 1  Physical Therapy (PTA) - Programs for the phys...
# 2                                                NaN

# %%
collegeOP
# Out:
# [
#          UUID: ec6cd5f4932aa7f57e11a1f3b2c26fa936a67648b4f3188f8c0faef7980f42587f6b67f04d70ceb2d8e52e6d9e606af9caa4d8503121cf95470d062ac71b15f6
#          Name: Community College of the Air Force
#          Address: 130 W Maxwell Blvd
#          City: Montgomery
#          Zip Code: 36112-6613
#          Web: www.maxwell.af.mil/au/ccaf/
#          Program Name: nan
#          ,
#          UUID: 9c11464fc0a0548d7d29595fed884a2f9d02c1717ee20de9c565b6befa179c8baba587545c98b6cd489028299f82b40110348c4fb24f4d93cc0342e8030ba69c
#          Name: Community College of the Air Force
#          Address: 130 W Maxwell Blvd
#          City: Montgomery
#          Zip Code: 36112-6613
#          Web: www.maxwell.af.mil/au/ccaf/
#          Program Name: Physical Therapy (PTA) - Programs for the physical therapist assistant
#          ,
#          UUID: 9d807c6c48405156567b2724078a3db89b0cd0f61cd3634b1ffd74c53b6dd559a26bd23a06c3dbeb92d3bf00c4e9838ec88f58a78896abffce28ebfb51e72b18
# ...
