# %%
import pandas as pd
import pickle as p

# %%
coordinates=pd.read_csv("../DATA/FirstSample.csv",index_col=False,encoding="utf-8")
colleges=pd.read_csv("../DATA/Colleges.csv",index_col=False,encoding="utf-8")

# %%
with open("../DATA/CollegeObjects.dat","rb") as f:
    collegeOP=p.load(f)
with open("../DATA/Locations.dat","rb") as f:
    locationsOP=p.load(f)

# %%
coordinates.head(3)
# Out:
#                              Name                                DMS  \
# 0  Hospital Providence of El Paso   ((31, 46, 14.0), (106, 30, 1.6))
# 1           Palmas Medical Center  ((31, 46, 12.3), (106, 29, 56.6))
# 2        Kindred Hospital El Paso  ((31, 46, 43.4), (106, 28, 38.1))
#
#                                           DD     LatitudeDMS     LongitudeDMS  \
# 0  (31.770555555555553, -106.50044444444444)  (31, 46, 14.0)   (106, 30, 1.6)
# 1  (31.770083333333332, -106.49905555555556)  (31, 46, 12.3)  (106, 29, 56.6)
# 2            (31.77872222222222, -106.47725)  (31, 46, 43.4)  (106, 28, 38.1)
#
#    LatitudeDD  LongitudeDD                                               UUID
# 0   31.770556  -106.500444  5ec1afd57f97de49598aed67032fb85db83644cbb582bc...
# 1   31.770083  -106.499056  beff07d3f35bbe0f33d4ac20dd33e46a0b4463aa80af1e...
# 2   31.778722  -106.477250  2f94ff04052e942c9fbcee3512a902a766940e9a1c0f0b...

# %%
locationsOP
# Out:
# OrderedDict([('Name',
#               ['Hospital Providence of El Paso',
#                'Palmas Medical Center',
#                'Kindred Hospital El Paso',
#                'El Paso Speciality Hospital',
#                'El Paso LTAC Hospital',
#                'Las Palmas Rehabilitation Center',
#                'Complete Care Community Hospital',
#                'William Beaumont Army Medical Center',
#                'University Medical Center Foundation',
#                'Hospital of Providence East Campus',
#                'Del Sol Medical Center']),
#              ('DMS',
#               [((31, 46, 14.0), (106, 30, 1.6)),
#                ((31, 46, 12.3), (106, 29, 56.6)),
#                ((31, 46, 43.4), (106, 28, 38.1)),
#                ((31, 46, 43.4), (106, 28, 39.0)),
#                ((31, 47, 1.6), (106, 28, 27.3)),
#                ((31, 47, 20.5), (106, 30, 31.9)),
#                ((31, 48, 3.6), (106, 30, 36.1)),
# ...

# %%
colleges.head(3)
# Out:
#                                  Name             Address        City  \
# 0  Community College of the Air Force  130 W Maxwell Blvd  Montgomery
# 1  Community College of the Air Force  130 W Maxwell Blvd  Montgomery
# 2            Alabama A & M University    4900 Meridian St      Normal
#
#           Zip                          Web  \
# 0  36112-6613  www.maxwell.af.mil/au/ccaf/
# 1  36112-6613  www.maxwell.af.mil/au/ccaf/
# 2       35762                www.aamu.edu/
#
#                                         Program Name
# 0                                                NaN
# 1  Physical Therapy (PTA) - Programs for the phys...
# 2                                                NaN

# %%
collegeOP
# Out:
# [
#          UUID: c9665812be72791358590940e49578a6a7539bab8b85953cfe11e233f3e11306c9ca068f0d124945d462b3336b53f5dfbac25a0da2c5f558f2cba9727d2f2a5d
#          Name: Community College of the Air Force
#          Address: 130 W Maxwell Blvd
#          City: Montgomery
#          Zip Code: 36112-6613
#          Web: www.maxwell.af.mil/au/ccaf/
#          Program Name: nan
#          ,
#          UUID: 8faeebdff9b7b2be83afe39dd369dbb52a90e6b70c9e1298bf2f6402fc8fa0083f887f3fabef5528c43518a6c923f2373e6e1686985398d432499bee045d259c
#          Name: Community College of the Air Force
#          Address: 130 W Maxwell Blvd
#          City: Montgomery
#          Zip Code: 36112-6613
#          Web: www.maxwell.af.mil/au/ccaf/
#          Program Name: Physical Therapy (PTA) - Programs for the physical therapist assistant
#          ,
#          UUID: eacb83da7452e9961fe965638878a82cfcd726d254dd13dbfd0e1f320493955194b897836d68e1f9442d735f18bd1573a1f5c4f3d123b6a1c3c8b4b268e80cde
# ...
