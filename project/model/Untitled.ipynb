# %%
import pandas as pd
import os

# %%
os.listdir("../data/")
# Out:
# ['ElPasoSortedRegistry.dat',
#  'Accreditation_04_2017.csv',
#  'ElPasoNameCoordinateMAP.dat',
#  'Locations.dat',
#  'CollegeObjects.dat',
#  'NameCoordinatesHOSPITAL.dat',
#  '.ipynb_checkpoints',
#  'ElPasoSortedHospitals.dat',
#  'Important.json',
#  'Colleges.xls',
#  'Colleges.csv',
#  '.~lock.FirstSample.xls#',
#  'ElPasoCoordinatesNameMAP.dat',
#  'NameCoordinates.dat',
#  'CoordinatesNameHOSPITAL.dat',
#  'Colleges.json']

# %%
df = pd.read_csv("../data/Colleges.csv")
df.head(3)
df.dro
# Out:
#                                  Name             Address        City  \
# 0  Community College of the Air Force  130 W Maxwell Blvd  Montgomery
# 1  Community College of the Air Force  130 W Maxwell Blvd  Montgomery
# 2            Alabama A & M University    4900 Meridian St      Normal
#
#           Zip                          Web  \
# 0  36112-6613  www.maxwell.af.mil/au/ccaf/
# 1  36112-6613  www.maxwell.af.mil/au/ccaf/
# 2       35762                www.aamu.edu/
#
#                                         Program Name
# 0                                                NaN
# 1  Physical Therapy (PTA) - Programs for the phys...
# 2                                                NaN

# %%
from py2neo import Graph, Node, Relationship

# %%
g = Graph("bolt://localhost:7687",auth=("neo4j","admin"))

# %%
for e in range(len(df)):
    s =""
    g.create(Relationship(Node("School",name=df["Name"][e],city=df["City"][e],address=df["Address"][e]),
            "PROGRAMS",
            Node("Program Name",name=df["Program Name"][e],school=df["Name"][e],web=df["Web"][e])))
    print(s)
    s = "Index of Data base:\t{}\tLength of Document:\t{}".format(e,len(df))
